# %% [markdown]
# # 作業
# - 作業目標 : 用 iris (dataset.load_iris()) 資料嘗試跑 hierarchical clustering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score, silhouette_samples
from sklearn import datasets
# %matplotlib inline

iris = datasets.load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# 載入 相關套件 並 執行 hierarchical clustering 實驗 ...

# %%
linkages = ['ward', 'complete', 'average']
n_clusters = [3,4,5,6,7]

for lk in linkages:
    for n in n_clusters:
        est = AgglomerativeClustering(n_clusters=n, linkage=lk)
        labels = est.fit_predict(X)
        score = silhouette_score(X, labels)
        
        print('for n =',n, 'and linkage =',lk,': the silhouette score is ',score)
        
        fig, ax = plt.subplots(1,1)
        ax.set_xlim([-0.1, 1])
        ax.set_ylim([0, len(X)+(n+1)*10])
        values = silhouette_samples(X, labels)
        
        y_lower = 10
        for i in range(n):
            ith_values = values[labels == i]
            ith_values.sort()
            
            size_i = ith_values.shape[0]
            y_upper = y_lower +size_i
            
            ax.fill_betweenx(np.arange(y_lower, y_upper), 0, ith_values)
            y_lower = y_upper+10
        plt.show()
# Out:
# for n = 3 and linkage = ward : the silhouette score is  0.5543236611296415
# for n = 4 and linkage = ward : the silhouette score is  0.4889670857554686
# for n = 5 and linkage = ward : the silhouette score is  0.48438258927905886
# for n = 6 and linkage = ward : the silhouette score is  0.3592376192603073
# for n = 7 and linkage = ward : the silhouette score is  0.3422071936620491
# for n = 3 and linkage = complete : the silhouette score is  0.5135953221192208
# for n = 4 and linkage = complete : the silhouette score is  0.4998128294171966
# for n = 5 and linkage = complete : the silhouette score is  0.3461739693026947
# for n = 6 and linkage = complete : the silhouette score is  0.33820313796201934
# for n = 7 and linkage = complete : the silhouette score is  0.32976490534004893
# for n = 3 and linkage = average : the silhouette score is  0.5541608580282847
# for n = 4 and linkage = average : the silhouette score is  0.4719936084994249
# ...
